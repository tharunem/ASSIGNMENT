# %% [markdown]
# # Step 1

# %% [markdown]
# **import lib**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Step 2

# %% [markdown]
# **import the dataset**

# %%
df=pd.read_excel('C:/Users/praka/Documents/py/Salary_Data.xlsx')

# %%
df
# Out:
#     Experience  Salary
# 0          1.1   39343
# 1          1.3   46205
# 2          1.5   37731
# 3          2.0   38500
# 4          2.2   39891
# 5          2.9   56642
# 6          3.0   60150
# 7          3.2   62000
# 8          3.2   64445
# 9          3.7   57189
# 10         3.9   63218
# 11         4.0   60000
# 12         4.0   56957
# 13         4.1   57081
# 14         4.5   61111
# 15         4.9   65000
# 16         5.1   66029
# 17         5.3   83088
# 18         5.9   81363
# 19         6.0   93940
# 20         6.8   91738
# 21         7.1   98273
# 22         7.9  101302
# 23         8.2  113812
# 24         8.7  109431
# 25         9.0  105582
# 26         9.5  116969
# 27         9.6  112635
# 28        10.3  122391
# 29        10.5  121872

# %%
df=pd.DataFrame(df,columns=['Experience','Salary'])

# %%
df.plot.scatter(x='Experience',y='Salary')
# Out:
# <AxesSubplot:xlabel='Experience', ylabel='Salary'>

# %%
x=df[['Experience']]

# %%
x
# Out:
#     Experience
# 0          1.1
# 1          1.3
# 2          1.5
# 3          2.0
# 4          2.2
# 5          2.9
# 6          3.0
# 7          3.2
# 8          3.2
# 9          3.7
# 10         3.9
# 11         4.0
# 12         4.0
# 13         4.1
# 14         4.5
# 15         4.9
# 16         5.1
# 17         5.3
# 18         5.9
# 19         6.0
# 20         6.8
# 21         7.1
# 22         7.9
# 23         8.2
# 24         8.7
# 25         9.0
# 26         9.5
# 27         9.6
# 28        10.3
# 29        10.5

# %%
y=df[['Salary']]

# %%
y
# Out:
#     Salary
# 0    39343
# 1    46205
# 2    37731
# 3    38500
# 4    39891
# 5    56642
# 6    60150
# 7    62000
# 8    64445
# 9    57189
# 10   63218
# 11   60000
# 12   56957
# 13   57081
# 14   61111
# 15   65000
# 16   66029
# 17   83088
# 18   81363
# 19   93940
# 20   91738
# 21   98273
# 22  101302
# 23  113812
# 24  109431
# 25  105582
# 26  116969
# 27  112635
# 28  122391
# 29  121872

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
xtrain
# Out:
#     Experience
# 27         9.6
# 11         4.0
# 17         5.3
# 22         7.9
# 5          2.9
# 16         5.1
# 8          3.2
# 14         4.5
# 23         8.2
# 20         6.8
# 1          1.3
# 29        10.5
# 6          3.0
# 4          2.2
# 18         5.9
# 19         6.0
# 9          3.7
# 7          3.2
# 25         9.0
# 3          2.0
# 0          1.1
# 21         7.1
# 15         4.9
# 12         4.0

# %%
ytrain
# Out:
#     Salary
# 27  112635
# 11   60000
# 17   83088
# 22  101302
# 5    56642
# 16   66029
# 8    64445
# 14   61111
# 23  113812
# 20   91738
# 1    46205
# 29  121872
# 6    60150
# 4    39891
# 18   81363
# 19   93940
# 9    57189
# 7    62000
# 25  105582
# 3    38500
# 0    39343
# 21   98273
# 15   65000
# 12   56957

# %%
xtest
# Out:
#     Experience
# 2          1.5
# 28        10.3
# 13         4.1
# 10         3.9
# 26         9.5
# 24         8.7

# %%
ytest
# Out:
#     Salary
# 2    37731
# 28  122391
# 13   57081
# 10   63218
# 26  116969
# 24  109431

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
predictions=lm.predict(xtest)

# %%
xtest
# Out:
#     Experience
# 2          1.5
# 28        10.3
# 13         4.1
# 10         3.9
# 26         9.5
# 24         8.7

# %%
predictions
# Out:
# array([[ 40966.27541089],
#        [122770.86830573],
#        [ 65135.81422073],
#        [ 63276.61892767],
#        [115334.08713347],
#        [107897.30596122]])

# %%
ytest
# Out:
#     Salary
# 2    37731
# 28  122391
# 13   57081
# 10   63218
# 26  116969
# 24  109431

# %%
predictions=pd.DataFrame(predictions,columns=['predictions'])

# %%
predictions
# Out:
#      predictions
# 0   40966.275411
# 1  122770.868306
# 2   65135.814221
# 3   63276.618928
# 4  115334.087133
# 5  107897.305961

# %%
sns.regplot(x='Experience',y='Salary',data=df,fit_reg=True)
# Out:
# <AxesSubplot:xlabel='Experience', ylabel='Salary'>
